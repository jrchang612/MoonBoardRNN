# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import keras
import copy
import tensorflow as tf
import seaborn as sn
import pandas as pd
import keras.backend as K
from keras.models import Sequential
from keras.layers.core import Activation, Dense
from keras.layers import Flatten, LSTM, Masking
from keras.models import Model
from keras.layers import Input
from sklearn import metrics
from model_helper import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1. Load in dataset

# %%
cwd = os.getcwd()
parent_wd = cwd.replace('/model', '')
training_set_path = parent_wd + '/preprocessing/training_seq_n_12_rmrp0'
dev_set_path = parent_wd + '/preprocessing/dev_seq_n_12_rmrp0'
test_set_path = parent_wd + '/preprocessing/test_seq_n_12_rmrp0'

# %%
with open(training_set_path, 'rb') as f:
    training_set = pickle.load(f)
with open(dev_set_path, 'rb') as f:
    dev_set = pickle.load(f)
with open(test_set_path, 'rb') as f:
    test_set = pickle.load(f)

# %%
X_train = training_set['X']
Y_train = training_set['Y']
X_dev = dev_set['X']
Y_dev = dev_set['Y']
X_test = test_set['X']
Y_test = test_set['Y']

# %% [markdown]
# ## 2. Define GradeNet Model

# %%
np.random.seed(0)
tf.random.set_seed(0)
inputs = Input(shape = (12, 22))
mask = Masking(mask_value = 0.).compute_mask(inputs)
lstm0 = LSTM(20, activation='tanh', input_shape=(12, 22), kernel_initializer='glorot_normal', return_sequences = 'True')(
    inputs, mask = mask)
dense1 = Dense(100, activation='relu', kernel_initializer='glorot_normal')(lstm0)
dense2 = Dense(80, activation='relu', kernel_initializer='glorot_normal')(dense1)
dense3 = Dense(75, activation='relu', kernel_initializer='glorot_normal')(dense2)
dense4 = Dense(50, activation='relu', kernel_initializer='glorot_normal')(dense3)
dense5 = Dense(20, activation='relu', kernel_initializer='glorot_normal')(dense4)
dense6 = Dense(10, activation='relu', kernel_initializer='glorot_normal')(dense5)
flat = Flatten()(dense6)
softmax2 = Dense(10, activation='softmax', name = 'softmax2')(flat)
lstm1 = LSTM(20, activation='tanh', kernel_initializer='glorot_normal', return_sequences = True)(dense6)
lstm2 = LSTM(20, activation='tanh', kernel_initializer='glorot_normal')(lstm1)
dense7 = Dense(15, activation='relu', kernel_initializer='glorot_normal')(lstm2)
dense8 = Dense(15, activation='relu', kernel_initializer='glorot_normal')(dense7)
softmax3 = Dense(10, activation='softmax', name = 'softmax2')(dense8)

def custom_loss(layer):
    def loss(y_true,y_pred):
        loss1 = K.sparse_categorical_crossentropy(y_true, y_pred)
        loss2 = K.sparse_categorical_crossentropy(y_true, layer)
        return K.mean(loss1 + loss2, axis=-1)
    return loss

GradeNet = Model(inputs=[inputs], outputs=[softmax3])
GradeNet.compile(optimizer='adam', 
                loss=custom_loss(softmax2),
                metrics=['sparse_categorical_accuracy'])

# %% [markdown]
# ## 2-1. Training of GradeNet
# ### To load pretrained weights, please skip to 2-2.

# %%
history_GradeNet_all = []

# %%
for i in range(10):
    history_GradeNet = GradeNet.fit(X_train, Y_train, epochs=10, batch_size=256, validation_data = (X_dev, Y_dev), 
                                class_weight = {0:1, 1:1, 2:2, 3: 2, 4: 1, 5: 4, 6:2, 7: 4, 8: 8, 9: 8})
    history_GradeNet_all.append(history_GradeNet)
# Out:
# Train on 20157 samples, validate on 2442 samples
# Epoch 1/10
# 20157/20157 [==============================] - 6s 314us/step - loss: 5.0519 - sparse_categorical_accuracy: 0.3964 - val_loss: 3.0839 - val_sparse_categorical_accuracy: 0.4611
# Epoch 2/10
# 20157/20157 [==============================] - 4s 205us/step - loss: 3.9058 - sparse_categorical_accuracy: 0.4842 - val_loss: 2.7690 - val_sparse_categorical_accuracy: 0.5094
# Epoch 3/10
# 20157/20157 [==============================] - 3s 169us/step - loss: 3.5944 - sparse_categorical_accuracy: 0.4947 - val_loss: 2.5628 - val_sparse_categorical_accuracy: 0.4996
# Epoch 4/10
# 20157/20157 [==============================] - 3s 169us/step - loss: 3.3471 - sparse_categorical_accuracy: 0.4997 - val_loss: 2.4615 - val_sparse_categorical_accuracy: 0.5074
# Epoch 5/10
# 20157/20157 [==============================] - 3s 172us/step - loss: 3.2468 - sparse_categorical_accuracy: 0.5036 - val_loss: 2.4079 - val_sparse_categorical_accuracy: 0.5217
# Epoch 6/10
# 20157/20157 [==============================] - 4s 182us/step - loss: 3.2197 - sparse_categorical_accuracy: 0.5022 - val_loss: 2.3955 - val_sparse_categorical_accuracy: 0.5123
# Epoch 7/10
# 20157/20157 [==============================] - 4s 176us/step - loss: 3.1743 - sparse_categorical_accuracy: 0.5074 - val_loss: 2.3721 - val_sparse_categorical_accuracy: 0.5106
# Epoch 8/10
# 20157/20157 [==============================] - 4s 174us/step - loss: 3.1647 - sparse_categorical_accuracy: 0.5079 - val_loss: 2.3523 - val_sparse_categorical_accuracy: 0.5233
# Epoch 9/10
# 20157/20157 [==============================] - 4s 175us/step - loss: 3.1442 - sparse_categorical_accuracy: 0.5117 - val_loss: 2.3403 - val_sparse_categorical_accuracy: 0.5197
# Epoch 10/10
# 20157/20157 [==============================] - 3s 172us/step - loss: 3.1313 - sparse_categorical_accuracy: 0.5133 - val_loss: 2.3346 - val_sparse_categorical_accuracy: 0.5213
# Train on 20157 samples, validate on 2442 samples
# Epoch 1/10
# 20157/20157 [==============================] - 3s 172us/step - loss: 3.1124 - sparse_categorical_accuracy: 0.5148 - val_loss: 2.3253 - val_sparse_categorical_accuracy: 0.5258
# Epoch 2/10
# 20157/20157 [==============================] - 4s 184us/step - loss: 3.1017 - sparse_categorical_accuracy: 0.5140 - val_loss: 2.3336 - val_sparse_categorical_accuracy: 0.5246
# Epoch 3/10
# 20157/20157 [==============================] - 4s 195us/step - loss: 3.0907 - sparse_categorical_accuracy: 0.5143 - val_loss: 2.3270 - val_sparse_categorical_accuracy: 0.5225
# Epoch 4/10
# 20157/20157 [==============================] - 3s 173us/step - loss: 3.0808 - sparse_categorical_accuracy: 0.5165 - val_loss: 2.3236 - val_sparse_categorical_accuracy: 0.5192
# Epoch 5/10
# 20157/20157 [==============================] - 4s 175us/step - loss: 3.0761 - sparse_categorical_accuracy: 0.5166 - val_loss: 2.3153 - val_sparse_categorical_accuracy: 0.5324
# Epoch 6/10
# 20157/20157 [==============================] - 4s 216us/step - loss: 3.0654 - sparse_categorical_accuracy: 0.5183 - val_loss: 2.3339 - val_sparse_categorical_accuracy: 0.5258
# Epoch 7/10
# 20157/20157 [==============================] - 3s 172us/step - loss: 3.0871 - sparse_categorical_accuracy: 0.5132 - val_loss: 2.3203 - val_sparse_categorical_accuracy: 0.5295
# Epoch 8/10
# Epoch 6/10
# 20157/20157 [==============================] - 3s 173us/step - loss: 2.8303 - sparse_categorical_accuracy: 0.5467 - val_loss: 2.3522 - val_sparse_categorical_accuracy: 0.5229
# Epoch 7/10
# 20157/20157 [==============================] - 4s 183us/step - loss: 2.8236 - sparse_categorical_accuracy: 0.5481 - val_loss: 2.3401 - val_sparse_categorical_accuracy: 0.5225
# Epoch 8/10
# 20157/20157 [==============================] - 4s 175us/step - loss: 2.8206 - sparse_categorical_accuracy: 0.5456 - val_loss: 2.3515 - val_sparse_categorical_accuracy: 0.5201
# Epoch 9/10
# 20157/20157 [==============================] - 4s 183us/step - loss: 2.8312 - sparse_categorical_accuracy: 0.5453 - val_loss: 2.4195 - val_sparse_categorical_accuracy: 0.4824
# Epoch 10/10
# 20157/20157 [==============================] - 4s 179us/step - loss: 2.8208 - sparse_categorical_accuracy: 0.5478 - val_loss: 2.3468 - val_sparse_categorical_accuracy: 0.5205
# Train on 20157 samples, validate on 2442 samples
# Epoch 1/10
# 20157/20157 [==============================] - 4s 175us/step - loss: 2.8224 - sparse_categorical_accuracy: 0.5484 - val_loss: 2.3420 - val_sparse_categorical_accuracy: 0.5258
# Epoch 2/10
# 20157/20157 [==============================] - 4s 179us/step - loss: 2.8088 - sparse_categorical_accuracy: 0.5500 - val_loss: 2.3379 - val_sparse_categorical_accuracy: 0.5242
# Epoch 3/10
# 20157/20157 [==============================] - 4s 182us/step - loss: 2.8172 - sparse_categorical_accuracy: 0.5486 - val_loss: 2.3576 - val_sparse_categorical_accuracy: 0.5139
# Epoch 4/10
# 20157/20157 [==============================] - 4s 176us/step - loss: 2.8040 - sparse_categorical_accuracy: 0.5520 - val_loss: 2.3409 - val_sparse_categorical_accuracy: 0.5283
# Epoch 5/10
# 20157/20157 [==============================] - 4s 175us/step - loss: 2.7991 - sparse_categorical_accuracy: 0.5478 - val_loss: 2.3588 - val_sparse_categorical_accuracy: 0.5201
# Epoch 6/10
# 20157/20157 [==============================] - 4s 175us/step - loss: 2.7921 - sparse_categorical_accuracy: 0.5568 - val_loss: 2.3826 - val_sparse_categorical_accuracy: 0.5041
# Epoch 7/10
# 20157/20157 [==============================] - 4s 175us/step - loss: 2.8052 - sparse_categorical_accuracy: 0.5491 - val_loss: 2.3766 - val_sparse_categorical_accuracy: 0.5225
# Epoch 8/10
# 20157/20157 [==============================] - 4s 174us/step - loss: 2.7987 - sparse_categorical_accuracy: 0.5543 - val_loss: 2.3482 - val_sparse_categorical_accuracy: 0.5299
# Epoch 9/10
# 20157/20157 [==============================] - 4s 190us/step - loss: 2.7925 - sparse_categorical_accuracy: 0.5492 - val_loss: 2.3814 - val_sparse_categorical_accuracy: 0.5131
# Epoch 10/10
# 20157/20157 [==============================] - 4s 175us/step - loss: 2.7867 - sparse_categorical_accuracy: 0.5514 - val_loss: 2.3689 - val_sparse_categorical_accuracy: 0.5238

# %%
# Change weights
for i in range(10):
    history_GradeNet = GradeNet.fit(X_train, Y_train, epochs=10, batch_size=256, validation_data = (X_dev, Y_dev), 
                                class_weight = {0:1, 1:1, 2:2, 3: 4, 4: 1, 5: 4, 6: 8, 7: 8, 8: 8, 9: 8})
    history_GradeNet_all.append(history_GradeNet)
# Out:
# Train on 20157 samples, validate on 2442 samples
# Epoch 1/10
# 20157/20157 [==============================] - 4s
# 20157/20157 [==============================] - 4s 178us/step - loss: 2.8702 - sparse_categorical_accuracy: 0.6340 - val_loss: 2.6604 - val_sparse_categorical_accuracy: 0.4836
# Epoch 6/10
# 20157/20157 [==============================] - 4s 180us/step - loss: 2.8733 - sparse_categorical_accuracy: 0.6325 - val_loss: 2.6309 - val_sparse_categorical_accuracy: 0.4857
# Epoch 7/10
# 20157/20157 [==============================] - 4s 178us/step - loss: 2.8693 - sparse_categorical_accuracy: 0.6327 - val_loss: 2.6418 - val_sparse_categorical_accuracy: 0.4828
# Epoch 8/10
# 20157/20157 [==============================] - 4s 188us/step - loss: 2.8561 - sparse_categorical_accuracy: 0.6366 - val_loss: 2.6402 - val_sparse_categorical_accuracy: 0.4803
# Epoch 9/10
# 20157/20157 [==============================] - 4s 190us/step - loss: 2.8647 - sparse_categorical_accuracy: 0.6325 - val_loss: 2.6657 - val_sparse_categorical_accuracy: 0.4906
# Epoch 10/10
# 20157/20157 [==============================] - 4s 219us/step - loss: 2.8534 - sparse_categorical_accuracy: 0.6357 - val_loss: 2.6899 - val_sparse_categorical_accuracy: 0.4767
# Train on 20157 samples, validate on 2442 samples
# Epoch 1/10
# 20157/20157 [==============================] - 4s 203us/step - loss: 2.8553 - sparse_categorical_accuracy: 0.6339 - val_loss: 2.6623 - val_sparse_categorical_accuracy: 0.4808
# Epoch 2/10
# 20157/20157 [==============================] - 4s 187us/step - loss: 2.8269 - sparse_categorical_accuracy: 0.6440 - val_loss: 2.6367 - val_sparse_categorical_accuracy: 0.4869
# Epoch 3/10
# 20157/20157 [==============================] - 4s 196us/step - loss: 2.8363 - sparse_categorical_accuracy: 0.6365 - val_loss: 2.7060 - val_sparse_categorical_accuracy: 0.5012
# Epoch 4/10
# 20157/20157 [==============================] - 4s 182us/step - loss: 2.8455 - sparse_categorical_accuracy: 0.6369 - val_loss: 2.6645 - val_sparse_categorical_accuracy: 0.4894
# Epoch 5/10
# 20157/20157 [==============================] - 4s 179us/step - loss: 2.8167 - sparse_categorical_accuracy: 0.6415 - val_loss: 2.7086 - val_sparse_categorical_accuracy: 0.4930
# Epoch 6/10
# 20157/20157 [==============================] - 4s 178us/step - loss: 2.8115 - sparse_categorical_accuracy: 0.6426 - val_loss: 2.6272 - val_sparse_categorical_accuracy: 0.4988
# Epoch 7/10
# 20157/20157 [==============================] - 4s 176us/step - loss: 2.8148 - sparse_categorical_accuracy: 0.6447 - val_loss: 2.6917 - val_sparse_categorical_accuracy: 0.4660
# Epoch 8/10
# 20157/20157 [==============================] - 4s 178us/step - loss: 2.8061 - sparse_categorical_accuracy: 0.6449 - val_loss: 2.6915 - val_sparse_categorical_accuracy: 0.4762
# Epoch 9/10
# 20157/20157 [==============================] - 4s 178us/step - loss: 2.7980 - sparse_categorical_accuracy: 0.6461 - val_loss: 2.6974 - val_sparse_categorical_accuracy: 0.4779
# Epoch 10/10
# 20157/20157 [==============================] - 4s 179us/step - loss: 2.7951 - sparse_categorical_accuracy: 0.6458 - val_loss: 2.7179 - val_sparse_categorical_accuracy: 0.4746

# %% [markdown]
# ### Plot training history

# %%
GradeNet_history_package = plot_history(history_GradeNet, 'GradeNet')

# %% [markdown]
# ### Save training results

# %%
# saving trained results
save_pickle(GradeNet_history_package, 'GradeNet_train_history')
GradeNet.save_weights("GradeNet.h5")

# %% [markdown]
# ## 2-2. Loading pretrained GradeNet

# %%
# load model weight
GradeNet.load_weights(parent_wd + '/model/GradeNet.h5')

# load training history
history_path = parent_wd + '/model/GradeNet_train_history'
with open(history_path, 'rb') as f:
    GradeNet_history_package = pickle.load(f)

plot_history_package(GradeNet_history_package, 'GradeNet')

# %% [markdown]
# ## 3. Analyze GradeNet Performance

# %% [markdown]
# ### Confusion Matrix

# %%
plot_confusion_matrix(Y_train, GradeNet.predict(X_train).argmax(axis=1), title = 'Confusion matrix of GradeNet(Training set)')

# %%
plot_confusion_matrix(Y_dev, GradeNet.predict(X_dev).argmax(axis=1), title = 'Confusion matrix of GradeNet(Dev set)')

# %%
plot_confusion_matrix(Y_test, GradeNet.predict(X_test).argmax(axis=1), title = 'Confusion matrix of GradeNet(Test set)')

# %% [markdown]
# ### F1 score

# %%
F1_train = metrics.f1_score(Y_train, GradeNet.predict(X_train).argmax(axis=1), average = 'macro')
print(F1_train)
# Out:
# 0.5057003231041498

# %%
F1_dev = metrics.f1_score(Y_dev, GradeNet.predict(X_dev).argmax(axis=1), average = 'macro')
print(F1_dev)
# Out:
# 0.2415038991517887

# %%
F1_test = metrics.f1_score(Y_test, GradeNet.predict(X_test).argmax(axis=1), average = 'macro')
print(F1_test)
# Out:
# 0.25462859135503807

# %% [markdown]
# ### Accuracy and Rough accuracy

# %%
accuracy_train = compute_accuracy(Y_train, GradeNet.predict(X_train).argmax(axis=1))
print("Exactly accuracy rate of training set = %s" %accuracy_train[0])
print("+/-1 Accuracy rate of training set= %s" %accuracy_train[1])
# Out:
# Exactly accuracy rate of training set = 0.6426551570174133
# +/-1 Accuracy rate of training set= 0.9129334722428933

# %%
accuracy_dev = compute_accuracy(Y_dev, GradeNet.predict(X_dev).argmax(axis=1))
print("Exactly accuracy rate of dev set = %s" %accuracy_dev[0])
print("+/-1 Accuracy rate of dev set = %s" %accuracy_dev[1])
# Out:
# Exactly accuracy rate of dev set = 0.4746109746109746
# +/-1 Accuracy rate of dev set = 0.8484848484848485

# %%
accuracy_test = compute_accuracy(Y_test, GradeNet.predict(X_test).argmax(axis=1))
print("Exactly accuracy rate of test set = %s" %accuracy_test[0])
print("+/-1 Accuracy rate of test set = %s" %accuracy_test[1])
# Out:
# Exactly accuracy rate of test set = 0.46655987184621545
# +/-1 Accuracy rate of test set = 0.8474169002803364

# %% [markdown]
# ### KL divergence

# %%
kl = tf.keras.losses.KLDivergence()

kld_train = kl(tf.one_hot(Y_train.astype(int), depth = 10), GradeNet.predict(X_train)).numpy()
print(kld_train)

kld_dev = kl(tf.one_hot(Y_dev.astype(int), depth = 10), GradeNet.predict(X_dev)).numpy()
print(kld_dev)

kld_test = kl(tf.one_hot(Y_test.astype(int), depth = 10), GradeNet.predict(X_test)).numpy()
print(kld_test)
# Out:
# 0.86333936
# 1.3504114
# 1.392339

# %% [markdown]
# ### Mean absolute error

# %%
# MAE
mae_train = np.mean(np.abs(Y_train - GradeNet.predict(X_train).argmax(axis=1)))
print(mae_train)

mae_dev = np.mean(np.abs(Y_dev - GradeNet.predict(X_dev).argmax(axis=1)))
print(mae_dev)

mae_test = np.mean(np.abs(Y_test - GradeNet.predict(X_test).argmax(axis=1)))
print(mae_test)
# Out:
# 0.4649997519472144
# 0.733005733005733
# 0.7404885863035643

# %% [markdown]
# ### Classification report

# %%
sk_report_train = metrics.classification_report(
    digits=4,
    y_true=Y_train, 
    y_pred=GradeNet.predict(X_train).argmax(axis=1))
print(sk_report_train)

sk_report_dev = metrics.classification_report(
    digits=4,
    y_true=Y_dev, 
    y_pred=GradeNet.predict(X_dev).argmax(axis=1))
print(sk_report_dev)

sk_report_test = metrics.classification_report(
    digits=4,
    y_true=Y_test, 
    y_pred=GradeNet.predict(X_test).argmax(axis=1))
print(sk_report_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0     0.7877    0.8243    0.8056      7285
#          1.0     0.6600    0.5874    0.6216      5625
#          2.0     0.4265    0.6566    0.5171      2586
#          3.0     0.3452    0.2468    0.2878      1811
#          4.0     0.6763    0.5135    0.5838      1961
#          5.0     0.6905    0.6000    0.6421       580
#          6.0     0.5732    0.4498    0.5040       209
#          7.0     0.5476    0.6053    0.5750        76
#          8.0     0.4000    0.2667    0.3200        15
#          9.0     1.0000    0.1111    0.2000         9
#
#     accuracy                         0.6427     20157
#    macro avg     0.6107    0.4861    0.5057     20157
# weighted avg     0.6490    0.6427    0.6398     20157
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          0.0     0.7086    0.7214    0.7149       883
#          1.0     0.4502    0.4182    0.4336       703
#          2.0     0.2453    0.3920    0.3018       301
#          3.0     0.2071    0.1584    0.1795       221
#          4.0     0.3671    0.2511    0.2982       231
#          5.0     0.2407    0.2031    0.2203        64
#          6.0     0.2308    0.0938    0.1333        32
#          7.0     0.1000    0.2000    0.1333         5
#          8.0     0.0000    0.0000    0.0000         1
#          9.0     0.0000    0.0000    0.0000         1
#
#     accuracy                         0.4746      2442
#    macro avg     0.2550    0.2438    0.2415      2442
# weighted avg     0.4791    0.4746    0.4728      2442
#
#               precision    recall  f1-score   support
#
#          0.0     0.6757    0.7263    0.7001       855
#          1.0     0.4637    0.4050    0.4324       726
#          2.0     0.2516    0.3533    0.2939       334
#          3.0     0.1875    0.1449    0.1635       207
#          4.0     0.3798    0.2937    0.3312       269
#          5.0     0.2090    0.1944    0.2014        72
#          6.0     0.3077    0.3810    0.3404        21
#          7.0     0.0769    0.0909    0.0833        11
#          8.0     0.0000    0.0000    0.0000         1
#          9.0     0.0000    0.0000    0.0000         1
#
#     accuracy                         0.4666      2497
#    macro avg     0.2552    0.2589    0.2546      2497
# weighted avg     0.4653    0.4666    0.4630      2497

# %%
AUC_train = metrics.roc_auc_score(Y_train, GradeNet.predict(X_train), multi_class= 'ovr', average="macro")
print(AUC_train)

AUC_dev = metrics.roc_auc_score(Y_dev, GradeNet.predict(X_dev), multi_class= 'ovr', average="macro")
print(AUC_dev)

AUC_test = metrics.roc_auc_score(Y_test, GradeNet.predict(X_test), multi_class= 'ovr', average="macro")
print(AUC_test)
# Out:
# 0.9422221701987953
# 0.8626394146312968
# 0.8701816011490345
